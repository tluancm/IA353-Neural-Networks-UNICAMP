# %% [markdown]
# ##**Notebook PC#09 - Part 1**
# ## Autoencoder training and manifold visualization for the MNIST database.
# ## Partially based on [this material](https://www.kaggle.com/apapiu/manifold-learning-and-autoencoders).
#
# **Professor:** Fernando J. Von Zuben <br>
# **Aluno(a):** Taylon Luan Congio Martins RA: 177379<br>
# **Aluno(a):** Tiago C A Amorim RA: 100675

# %% [markdown]
# ### Loading the main libraries

# %%
import tensorflow as tf
import os

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Convolution2D, MaxPooling2D, Flatten, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
from keras.utils import to_categorical

# %% [markdown]
# ### Reading the data

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
x_images = x_train.reshape(x_train.shape[0], 28, 28)

# %%
# Definition of a function to visualize some digits
def show(img):
    plt.imshow(img, cmap = "gray", interpolation = "none")

# %%
# Visualization of 25 x 25 original images of digits
fig = plt.figure(figsize=(28,28))
ind = 1
for i in range(1, 26, 1):
    for j in range(1, 26, 1):
        fig.add_subplot(25,25,ind)
        show(x_images[ind])
        plt.xticks([])
        plt.yticks([])
        ind+=1

# %% [markdown]
# ### Proposal for the autoencoder architecture

# %%
input_img = Input(shape=(784,))

encoded = Dense(512, activation='tanh')(input_img)
encoded = Dense(128, activation='tanh')(encoded)
encoded = Dense(32, activation='tanh')(encoded)

encoded = Dense(2)(encoded) # Linear activation function at the bottleneck

decoded = Dense(32, activation='tanh')(encoded)
decoded = Dense(128, activation='tanh')(decoded)
decoded = Dense(512, activation='tanh')(decoded)

decoded = Dense(784, activation = 'sigmoid')(decoded)

autoencoder = Model(input_img, decoded)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 32)                4128
#
#  dense_3 (Dense)             (None, 2)                 66
#
#  dense_4 (Dense)             (None, 32)                96
#
#  dense_5 (Dense)             (None, 128)               4224
#
#  dense_6 (Dense)             (None, 512)               66048
#
#  dense_7 (Dense)             (None, 784)               402192
#
# =================================================================
# Total params: 944338 (3.60 MB)
# Trainable params: 944338 (3.60 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
autoencoder.compile(optimizer = "adam", loss = "mse")
X = x_train.reshape(x_train.shape[0], 784)
history = autoencoder.fit(X, X, batch_size = 128, epochs = 50, verbose = 1)
# Out:
# Epoch 1/50
# 469/469 [==============================] - 7s 4ms/step - loss: 0.0657
# Epoch 2/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0511
# Epoch 3/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0453
# Epoch 4/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0424
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0405
# Epoch 6/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0395
# Epoch 7/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0387
# Epoch 8/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0381
# Epoch 9/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0375
# Epoch 10/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0370
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0368
# Epoch 12/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0365
# Epoch 13/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0363
# Epoch 14/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0361
# Epoch 15/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0357
# Epoch 16/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0355
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0353
# Epoch 18/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0352
# Epoch 19/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0350
# Epoch 20/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0350
# Epoch 21/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0347
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0346
# Epoch 23/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0345
# Epoch 24/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0344
# Epoch 25/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0343
# Epoch 26/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0342
# Epoch 27/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0341
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0341
# Epoch 29/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0339
# Epoch 30/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0339
# Epoch 31/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0337
# Epoch 32/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0337
# Epoch 33/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0337
# Epoch 34/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0336
# Epoch 35/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0336
# Epoch 36/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0335
# Epoch 37/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0335
# Epoch 38/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0334
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0334
# Epoch 40/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0333
# Epoch 41/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0332
# Epoch 42/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0332
# Epoch 43/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0331
# Epoch 44/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0329
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0329
# Epoch 46/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0329
# Epoch 47/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0329
# Epoch 48/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0329
# Epoch 49/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0329
# Epoch 50/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0328

# %%
plot_df = pd.DataFrame.from_dict({'train_loss':history.history['loss']})
plot_df.plot(logy=True, figsize=(15,5), fontsize=12)
plt.xlabel('epoch', fontsize=12)
plt.ylabel('loss', fontsize=12)
plt.show()

# %%
# Visualization of 25 x 25 reconstructed images of digits
fig = plt.figure(figsize=(28,28))
ind = 1
for i in range(1, 26, 1):
    for j in range(1, 26, 1):
        fig.add_subplot(25,25,ind)
        show(autoencoder.predict(np.expand_dims(x_images[ind].flatten(), 0), verbose = False).reshape(28, 28))
        plt.xticks([])
        plt.yticks([])
        ind+=1

# %%
encoder = Model(input_img, encoded)

# Building the decoder
encoded_input = Input(shape=(2,))
encoded_layer_1 = autoencoder.layers[-4]
encoded_layer_2 = autoencoder.layers[-3]
encoded_layer_3 = autoencoder.layers[-2]
encoded_layer_4 = autoencoder.layers[-1]

decoder = encoded_layer_1(encoded_input)
decoder = encoded_layer_2(decoder)
decoder = encoded_layer_3(decoder)
decoder = encoded_layer_4(decoder)
decoder = Model(encoded_input, decoder)

# %% [markdown]
# ### Visualizing the images in the manifold

# %%
# Using encoder to visualize the manifold

import seaborn as sns

x_flat = x_train.reshape(x_train.shape[0], x_train.shape[1] * x_train.shape[2])

x_proj = encoder.predict(x_flat[:60000])
x_proj.shape

proj = pd.DataFrame(x_proj)
proj.columns = ["comp_1", "comp_2"]
proj["labels"] = y_train[:60000]
sns.lmplot(x = "comp_1", y = "comp_2", hue="labels", data=proj, fit_reg=False, logx = True)
# Out:
# 1875/1875 [==============================] - 3s 1ms/step

# %% [markdown]
# ### Generating new digits by moving along the manifold (latent 2D space)
# **Please, adjust the scale whenever necessary.**

# %% [markdown]
# ### Moving along a circle

# %%
_ = sns.lmplot(x = "comp_1", y = "comp_2", hue="labels", data=proj, fit_reg=False)
all_x = [3.5 * np.cos(2 * np.pi / 100 * i) + -2 for i in range(100)]
all_y = [3.5 * np.sin(2 * np.pi / 100 * i) - 1.6 for i in range(100)]
_ = plt.plot(all_x, all_y, 'black')

# %%
# moving along a circle:
_ = plt.figure(figsize=(10, 10))

for i in range(100):
    _ = plt.subplot(10, 10, i+1)

    x = 3.5 * np.cos(2 * np.pi / 100 * i) + -2
    y = 3.5 * np.sin(2 * np.pi / 100 * i) - 1.6

    pt = np.array([[x, y]])
    _ = show(decoder.predict(pt, verbose = False).reshape((28, 28)))
    _ = plt.xticks([])
    _ = plt.yticks([])

# %% [markdown]
# ### Moving along an ellipse

# %%
_ = sns.lmplot(x = "comp_1", y = "comp_2", hue="labels", data=proj, fit_reg=False)
all_x = [2 * np.cos(2 * np.pi / 100 * i) + -2 for i in range(100)]
all_y = [6 * np.sin(2 * np.pi / 100 * i) + -1 for i in range(100)]
_ = plt.plot(all_x, all_y, 'black')

# %%
# Moving along an ellipse:
_ = plt.figure(figsize=(10, 10))

for i in range(100):
    _ = plt.subplot(10, 10, i+1)

    x = 2 * np.cos(2 * np.pi / 100 * i) + -2
    y = 6 * np.sin(2 * np.pi / 100 * i) + -1

    pt = np.array([[x, y]])
    _ = show(decoder.predict(pt, verbose = False).reshape((28, 28)))
    _ = plt.xticks([])
    _ = plt.yticks([])

# %% [markdown]
# ### Moving along a grid

# %%
pt_x = []
pt_y = []
for i in range(20):
    for j in range(20):
        pt_x.append(-6.7 + 10 * i / 19)
        pt_y.append(-6.1 + 10 * j / 19)
_ = sns.lmplot(x = "comp_1", y = "comp_2", hue="labels", data=proj, fit_reg=False)
_ = sns.scatterplot(x = pt_x,y = pt_y, color = 'black', size = 0.5, legend = False )

# %%
# Moving along a grid:
_ = plt.figure(figsize=(12, 12))

for i in range(20):
    for j in range(20):

        _ = plt.subplot(20, 20, i * 20 + j + 1)

        pt = np.array([[ -6.7 + 10 * i / 19, -6.1 + 10 * j / 19]])
        _ = show(decoder.predict(pt, verbose = False).reshape((28, 28)))
        _ = plt.xticks([])
        _ = plt.yticks([])
